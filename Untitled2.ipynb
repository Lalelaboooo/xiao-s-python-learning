# %%
getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80c72379bb65> in <module>()
# ----> 1 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
import os
pwd = os.getcwd()

# %%
pwd
# Out:
# '/Users/hanxiao'
