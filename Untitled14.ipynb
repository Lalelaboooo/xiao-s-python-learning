# %%
import matplotlib.pyplot as plt

# %%
a = 3

# %%
b = 6

# %%
plt.plot(a,b)

# %%
a = 1

# %%
b = 2

# %%
plt.plot(a, b)

# %%
k = 5

# %%
plt.plot(5)

# %%
plt.plot(2,4)

# %%
plt.plot(0,0)

# %%
plt.plot(2,4,6)

# %%
def liner(a, b , k):
    y = a + b + k*y

# %%
plt.plot(0,liner)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b77aecefd845> in <module>()
# ----> 1 plt.plot(0,liner)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1527
# ...
