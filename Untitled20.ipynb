# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

housing = ['own','own','own','free','free','free','own','rent','own','own',
           'rent','rent','own','own','rent','own','own','own','free',\
           'own','own']
gender = ['male','female','male','male','male','male','male','male','male',\
       'male','female','female','female','male','female','female','male',\
       'male','female','male','male','male']

count_own = 0
count_rent = 0
for i in housing:
	if i == 'own':
		count_own+=1
	else:
		count_rent+=1

print("own housing: ",count_own)
print("No housing: ",count_rent)
print("Total number: ",count_own+count_rent)

female = 0
male = 0
for j in gender:
	if j == 'male':
		male+=1
	else:
		female+=1

print("male: ",male)
print("female: ",female)
print("Total: ",male+female)

plt.figure(figsize = (count_own,count_rent))
# Out:
# own housing:  13
# No housing:  8
# Total number:  21
# male:  15
# female:  7
# Total:  22

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

housing = ['own','own','own','free','free','free','own','rent','own','own',
           'rent','rent','own','own','rent','own','own','own','free',\
           'own','own']
gender = ['male','female','male','male','male','male','male','male','male',\
       'male','female','female','female','male','female','female','male',\
       'male','female','male','male','male']

count_own = 0
count_rent = 0
for i in housing:
	if i == 'own':
		count_own+=1
	else:
		count_rent+=1

print("own housing: ",count_own)
print("No housing: ",count_rent)
print("Total number: ",count_own+count_rent)

female = 0
male = 0
for j in gender:
	if j == 'male':
		male+=1
	else:
		female+=1

print("male: ",male)
print("female: ",female)
print("Total: ",male+female)

plt.figure(figsize = (count_own,count_rent))
plt.show()
# Out:
# own housing:  13
# No housing:  8
# Total number:  21
# male:  15
# female:  7
# Total:  22

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

housing = ['own','own','own','free','free','free','own','rent','own','own',
           'rent','rent','own','own','rent','own','own','own','free',\
           'own','own']
gender = ['male','female','male','male','male','male','male','male','male',\
       'male','female','female','female','male','female','female','male',\
       'male','female','male','male','male']

count_own = 0
count_rent = 0
for i in housing:
	if i == 'own':
		count_own+=1
	else:
		count_rent+=1

print("own housing: ",count_own)
print("No housing: ",count_rent)
print("Total number: ",count_own+count_rent)

female = 0
male = 0
for j in gender:
	if j == 'male':
		male+=1
	else:
		female+=1

print("male: ",male)
print("female: ",female)
print("Total: ",male+female)

plt.figure(figsize = (count_own,count_rent))
plt.xlabel = (0,female)
plt.ylabel = (0,male)
plt.show()
# Out:
# own housing:  13
# No housing:  8
# Total number:  21
# male:  15
# female:  7
# Total:  22

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(-1,1,50)

# %%
y = x*2 +1

# %%
plt.plot(x,y)

# %%
plt.figer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-eb84f23c1652> in <module>()
# ----> 1 plt.figer()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figer'

# %%
plt.figure()

# %%
plt.plot(count_own)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-33489a52d9e4> in <module>()
# ----> 1 plt.plot(count_own)
#
# NameError: name 'count_own' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

housing = ['own','own','own','free','free','free','own','rent','own','own',
           'rent','rent','own','own','rent','own','own','own','free',\
           'own','own']
gender = ['male','female','male','male','male','male','male','male','male',\
       'male','female','female','female','male','female','female','male',\
       'male','female','male','male','male']

count_own = 0
count_rent = 0
for i in housing:
	if i == 'own':
		count_own+=1
	else:
		count_rent+=1

print("own housing: ",count_own)
print("No housing: ",count_rent)
print("Total number: ",count_own+count_rent)

female = 0
male = 0
for j in gender:
	if j == 'male':
		male+=1
	else:
		female+=1

print("male: ",male)
print("female: ",female)
print("Total: ",male+female)
# Out:
# own housing:  13
# No housing:  8
# Total number:  21
# male:  15
# female:  7
# Total:  22

# %%
plt.plot(own housing,No housing)
# Out:
#   File "<ipython-input-10-0dc3a85514af>", line 1
#     plt.plot(own housing,No housing)
#                        ^
# SyntaxError: invalid syntax

# %%
plt.plot(own_housing,No housing)
# Out:
#   File "<ipython-input-11-679a0299f131>", line 1
#     plt.plot(own_housing,No housing)
#                                   ^
# SyntaxError: invalid syntax

# %%
plt.plot(own_housing,No_housing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6be018e28edd> in <module>()
# ----> 1 plt.plot(own_housing,No_housing)
#
# NameError: name 'own_housing' is not defined

# %%
y2 = x **2

# %%
plt.plot(x,y)

# %%
plt.plot(x,y2)

# %%
plt.figure()

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2)

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,colur='orange',linewidth=8,linestyle='==')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1110                 try:
# -> 1111                     ls = ls_mapper_r[ls]
#    1112                 except KeyError:
#
# KeyError: '=='
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-98ec5b88c4d5> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.plot(x,y2,colur='orange',linewidth=8,linestyle='==')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,colur='orange',linewidth=8,linestyle='--')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a3e62cf266c4> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.plot(x,y2,colur='orange',linewidth=8,linestyle='--')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='orange',linewidth=8,linestyle='==')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1110                 try:
# -> 1111                     ls = ls_mapper_r[ls]
#    1112                 except KeyError:
#
# KeyError: '=='
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f666aa809ab6> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.plot(x,y2,color='orange',linewidth=8,linestyle='==')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='orange',linewidth=8,linestyle='--')

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,colur='orange',linewidth=3.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-798a7470ca9d> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.plot(x,y2,colur='orange',linewidth=3.0)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='orange',linewidth=3)~/.matplotlib

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='orange',linewidth=3)
plt.xlim((0,75))
plt.ylim((0,75))
plt.shw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1c32b76e75e0> in <module>()
#       4 plt.xlim((0,75))
#       5 plt.ylim((0,75))
# ----> 6 plt.shw()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shw'

# %%
x = [0,25,50,75,100]

# %%
y = [0,25,50,75,100]

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='orange',linewidth=3)
plt.xlim((0,100))
plt.tylim((0,100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-70743419bc98> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.plot(x,y2,color='orange',linewidth=3)
#       4 plt.xlim((0,100))
#       5 plt.tylim((0,100))
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
# ...

# %%
plt.figure()
plt.plot(x,y)
plt.xlim((0,100))
plt.tylim((0,100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-60ff849acd82> in <module>()
#       2 plt.plot(x,y)
#       3 plt.xlim((0,100))
# ----> 4 plt.tylim((0,100))
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tylim'

# %%
plt.figure()
plt.plot(x,y)
plt.xlim((0,100,10))
plt.tylim((0,100,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-80899a47321f> in <module>()
#       1 plt.figure()
#       2 plt.plot(x,y)
# ----> 3 plt.xlim((0,100,10))
#       4 plt.tylim((0,100,10))
#       5 plt.show()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in xlim(*args, **kwargs)
#    1551     if not args and not kwargs:
#    1552         return ax.get_xlim()
# -> 1553     ret = ax.set_xlim(*args, **kwargs)
#    1554     return ret
#    1555
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, **kw)
#    3134
#    3135         if right is None and iterable(left):
# -> 3136             left, right = left
#    3137
#    3138         self._process_unit_info(xdata=(left, right))
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.plot(x,y)

# %%
x = np.linspace((-1,1,50))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3ae538b8f0b7> in <module>()
# ----> 1 x = np.linspace((-1,1,50))
#
# TypeError: linspace() missing 1 required positional argument: 'stop'

# %%
x = np.linspace(-1,1,50)

# %%
y = x *2 +1

# %%
y2 = x**2

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
x_axis = np.arange(1,10)

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
x_axis = np.arange(1,10)
plt.xticks(x_axis)
# Out:
# ([<matplotlib.axis.XTick at 0x11d9d7e80>,
# ...
#  <a list of 9 Text xticklabel objects>)

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')
plt.xlim(-1,2)
plt.ylim(-2,3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
x_axis = np.arange(1,10)
y_axis = np.linspace(1,10)
plt.xticks(x_axis)
plt.yticks(y_axis)
# Out:
# ([<matplotlib.axis.YTick at 0x11d93f940>,
# ...
#  <a list of 50 Text yticklabel objects>)

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')
#plt.xlim(-1,2)
#plt.ylim(-2,3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
x_axis = np.arange(-1,2,5)
y_axis = np.linspace(1h,10)
# Out:
#   File "<ipython-input-40-40a349c24784>", line 9
#     y_axis = np.linspace(1h,10)
#                           ^
# SyntaxError: invalid syntax

# %%
plt.figure()
plt.plot(x,y)
plt.plot(x,y2,color='red',linewidth = 1.0,linestyle='--')
#plt.xlim(-1,2)
#plt.ylim(-2,3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
x_axis = np.arange(-1,2,5)
y_axis = np.linspace(1,10)

# %%
housing
# Out:
# ['own',
#  'own',
#  'own',
#  'free',
#  'free',
#  'free',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'rent',
#  'rent',
#  'own',
#  'own',
#  'rent',
#  'own',
#  'own',
#  'own',
#  'free',
#  'own',
#  'own']

# %%
own in housing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-16bdf2564158> in <module>()
# ----> 1 own in housing
#
# NameError: name 'own' is not defined

# %%
'own' = housing
# Out:
#   File "<ipython-input-44-2a3e933f848f>", line 1
#     'own' = housing
#                    ^
# SyntaxError: can't assign to literal

# %%
'own' in housing
# Out:
# True

# %%
'own' == housing
# Out:
# False

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-c5d84736ba45> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/hanxiao'

# %%
data = pd.read_csv('supplier_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-7c209d141133> in <module>()
# ----> 1 data = pd.read_csv('supplier_data.csv')
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...
